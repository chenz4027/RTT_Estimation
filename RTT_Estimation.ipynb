# %%
#import CSV
import pandas as pd 
data = pd.read_csv("test.csv", dtype={'Source':'str','Destination':'str','Info':'str'}) 
data.head()
# Out:
#    No.      Time        Source   Destination Protocol  Length  \
# 0    1  0.000000    244.3.90.4  41.177.98.92      SSH     134
# 1    2  0.000075  41.177.98.92    244.3.90.4      SSH    1438
# 2    3  0.000105  41.177.98.92    244.3.90.4      SSH    1438
# 3    4  0.000144    244.3.90.4  41.177.98.92      TCP      70
# 4    5  0.000324  41.177.98.92    244.3.90.4      SSH    1438
#
#                                                 Info
# 0                  Client: Encrypted packet (len=64)
# 1                Server: Encrypted packet (len=1368)
# 2                Server: Encrypted packet (len=1368)
# 3  59984  >  22 [ACK] Seq=65 Ack=2737 Win=65535 L...
# 4                Server: Encrypted packet (len=1368)

# %%
# from scapy.layers.inet import *
# import time

# start = time.time()
# #filename='sm.pcap'
# filename='full.pcap'
# print("Begun to read packets")
# reader = PcapReader(filename)
# print("Finished reading packets")

# %%
df = pd.DataFrame(data)
df.dtypes
# Out:
# No.              int64
# Time           float64
# Source          object
# Destination     object
# Protocol        object
# Length           int64
# Info            object
# dtype: object

# %%
source = '41.177.26.176'
destination = '77.197.210.77'

# %%
#df[df['Source']==('244.3.90.4'|'41.177.98.92')]

# %%
df_sender = df[(df['Source'] == source) & (df['Destination'] == destination)]
df_sender.head()
# Out:
#        No.      Time         Source    Destination Protocol  Length  \
# 4939  4940  0.312573  41.177.26.176  77.197.210.77      TCP    1518
# 4940  4941  0.312578  41.177.26.176  77.197.210.77      TCP    1028
# 4942  4943  0.312724  41.177.26.176  77.197.210.77      TCP    1518
# 4943  4944  0.312728  41.177.26.176  77.197.210.77      TCP      64
# 6205  6206  0.391994  41.177.26.176  77.197.210.77      TCP    1518
#
#                                                    Info
# 4939  80  >  53705 [ACK] Seq=1 Ack=1 Win=64240 Len=1460
# 4940  80  >  53705 [PSH, ACK] Seq=1461 Ack=1 Win=642...
# 4942  80  >  53705 [ACK] Seq=2431 Ack=1 Win=64240 Le...
# 4943  80  >  53705 [PSH, ACK] Seq=3891 Ack=1 Win=642...
# 6205  80  >  53705 [ACK] Seq=3896 Ack=1 Win=64240 Le...

# %%
df_receiver = df[(df['Source'] == destination) & (df['Destination'] == source)]
df_receiver.head()
# Out:
#        No.      Time         Source    Destination Protocol  Length  \
# 6193  6194  0.391446  77.197.210.77  41.177.26.176      TCP      64
# 6194  6195  0.391450  77.197.210.77  41.177.26.176      TCP      64
# 7372  7373  0.470827  77.197.210.77  41.177.26.176      TCP      64
# 7373  7374  0.470832  77.197.210.77  41.177.26.176      TCP      64
# 7377  7378  0.470950  77.197.210.77  41.177.26.176      TCP      64
#
#                                                    Info
# 6193  53705  >  80 [ACK] Seq=1 Ack=2431 Win=65535 Len=0
# 6210    80  >  53705 [ACK] Seq=7530 Ack=1 Win=64240 Le...
# 6211    80  >  53705 [ACK] Seq=7790 Ack=1 Win=64240 Le...
# 6212    80  >  53705 [ACK] Seq=9250 Ack=1 Win=64240 Le...
# 6213    80  >  53705 [PSH, ACK] Seq=10391 Ack=1 Win=64...
# 7372    53705  >  80 [ACK] Seq=1 Ack=6070 Win=65535 Len=0
# 7373    53705  >  80 [ACK] Seq=1 Ack=7790 Win=65535 Len=0
# 7377    53705  >  80 [ACK] Seq=1 Ack=10391 Win=65535 L...
# 7383    53705  >  80 [RST, ACK] Seq=1 Ack=11073 Win=0 ...
# 8896    53786  >  80 [SYN] Seq=0 Win=65535 Len=0 MSS=1...
# 8900    80  >  53786 [SYN, ACK] Seq=0 Ack=1 Win=64240 ...
# 10247      53786  >  80 [ACK] Seq=1 Ack=1 Win=65535 Len=0
# 10296   53786  >  80 [PSH, ACK] Seq=1 Ack=1 Win=65535 ...
# 10306    80  >  53786 [ACK] Seq=1 Ack=301 Win=64240 Len=0
# 15436   80  >  53786 [PSH, ACK] Seq=1 Ack=301 Win=6424...
# 15438   80  >  53786 [ACK] Seq=1138 Ack=301 Win=64240 ...
# 15439   80  >  53786 [PSH, ACK] Seq=2598 Ack=301 Win=6...
# 15443   80  >  53786 [PSH, ACK] Seq=2717 Ack=301 Win=6...
# 15444   80  >  53786 [PSH, ACK] Seq=3870 Ack=301 Win=6...
# 16800   53786  >  80 [ACK] Seq=301 Ack=2717 Win=65416 ...
# 16801   53786  >  80 [ACK] Seq=301 Ack=3917 Win=64216 ...
# 16811   80  >  53786 [ACK] Seq=3917 Ack=301 Win=64240 ...
# ...                                                   ...
# 943206  80  >  15660 [ACK] Seq=9002 Ack=309 Win=64240 ...
# 943207  80  >  15660 [PSH, ACK] Seq=10462 Ack=309 Win=...
# 944740  15660  >  80 [ACK] Seq=309 Ack=11068 Win=65535...
# 944941  15660  >  80 [RST, ACK] Seq=309 Ack=11068 Win=...
# 945690  15787  >  80 [SYN] Seq=0 Win=65535 Len=0 MSS=1...
# 945703  80  >  15787 [SYN, ACK] Seq=0 Ack=1 Win=64240 ...
# 947133     15787  >  80 [ACK] Seq=1 Ack=1 Win=65535 Len=0
# 947137  15787  >  80 [PSH, ACK] Seq=1 Ack=1 Win=65535 ...
# 947140   80  >  15787 [ACK] Seq=1 Ack=356 Win=63885 Len=0
# 955341  80  >  15787 [ACK] Seq=1 Ack=356 Win=64240 Len...
# 955342  80  >  15787 [PSH, ACK] Seq=1461 Ack=356 Win=6...
# 955345  80  >  15787 [ACK] Seq=2431 Ack=356 Win=64240 ...
# 957159  15787  >  80 [ACK] Seq=356 Ack=2431 Win=65535 ...
# 957164  80  >  15787 [ACK] Seq=3891 Ack=356 Win=64240 ...
# 957165  80  >  15787 [ACK] Seq=5351 Ack=356 Win=64240 ...
# 957167  80  >  15787 [ACK] Seq=6483 Ack=356 Win=64240 ...
# 958768  15787  >  80 [ACK] Seq=356 Ack=5351 Win=65535 ...
# 958769  15787  >  80 [ACK] Seq=356 Ack=7943 Win=65535 ...
# 958775  80  >  15787 [ACK] Seq=7943 Ack=356 Win=64240 ...
# 958777  80  >  15787 [ACK] Seq=8832 Ack=356 Win=64240 ...
# 958780  80  >  15787 [ACK] Seq=10292 Ack=356 Win=64240...
# 958781  80  >  15787 [PSH, ACK] Seq=11752 Ack=356 Win=...
# 960558  15787  >  80 [ACK] Seq=356 Ack=12391 Win=65227...
# 960559  [TCP Dup ACK 960559#1] 15787  >  80 [ACK] Seq=...
# 960649  15787  >  80 [RST, ACK] Seq=356 Ack=12391 Win=...
# 962622  15967  >  80 [SYN] Seq=0 Win=65535 Len=0 MSS=1...
# 962625  80  >  15967 [SYN, ACK] Seq=0 Ack=1 Win=64240 ...
# 964184     15967  >  80 [ACK] Seq=1 Ack=1 Win=65535 Len=0
# 964189  15967  >  80 [PSH, ACK] Seq=1 Ack=1 Win=65535 ...
# 964194   80  >  15967 [ACK] Seq=1 Ack=308 Win=64240 Len=0
#
# [1082 rows x 7 columns]

# %%
# ACKinit = 0
# srtt = []
# for i in range(len(df_sort['Info'])):
#     if("ACK" in df_sort['Info']):
#         RTT=df_sort['Time'] - ACKinit
#         srtt.append(RTT)
#         ACKinit=RTT

# # for index, row in df_sort.iterrows():
# print(srtt)

# %%
ACKinit=0
srtt=[]
for i, row in df_sort.iterrows():
    if ('ACK' in row['Info']):
        ACKinit=row['Time']
        srtt.append(ACKinit)
        #     if ("ACK" in df_sort['Info']):

# %%
srtt[1]
# Out:
# 0.312578

# %%
ertt=[]
alpha=1/8
prtt=0
for i in range(len(srtt)):
     prtt = (1 - alpha) * srtt[i] + alpha * (srtt[i]/2)
     ertt.append(prtt)

# %%
ertt[1]
# Out:
# 0.293041875

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.kdeplot(srtt, bw=0, label="Sample RTT")
sns.kdeplot(ertt, bw=0, label="Estimate RTT")
plt.legend();

# %%
import math as math
mrtt = []
median = 0
index = 0
for i in range(len(ertt)):
    if i == 0:
        median = ertt[0]
        mrtt.append(median)
    elif i == 1:
        median = (ertt[0] + ertt[1])/2
        mrtt.append(median)
        
    elif (i+1)%2 != 0:
            index = i/2
            median = ertt[int(i/2)]
            mrtt.append(median)
    else:
        median = (ertt[int((i-1)/2)] + ertt[int((i+1)/2)]) / 2
        mrtt.append(median)

# %%
# mrtt

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.kdeplot(ertt, bw=0, label="Estimate RTT")
sns.kdeplot(mrtt, bw=0, label="Median RTT")
plt.legend();
